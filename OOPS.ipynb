# %% [markdown]
# Basic Class & Class Variables

# %%
class human():    # Class  named human
  hair='brown'    # Class variable shared by all objects
  nose='sharp'
  voice='sweet'

  def walk(self):   # Method definition, self refers to current object
    return 'I can walk'
  def speak(self):  # Another instance method
    return 'I can speak'

human.hair  # Accessing class variable using class name
# Out:
# 'brown'

# %%
human.walk('self')
# Out:
# 'I can walk'

# %%
class human():
  hair='brown'
  nose='sharp'
  voice='sweet'

  def walk(self):
    return 'I can walk'
  def speak(self):
    return 'I can speak'

# OBJECT CREATION
obj=human()

# %%
obj.walk()  # Calling walk() method using object
# Out:
# 'I can walk'

# %%
# ANIMAL CLASS
class Animal():
  eyes='black'
  nose='white'
  nails='sharp'
  tail='big'
  hairs='white'
  height='tall'

  def bark(self):
    return 'dog can bark'
  def run(self):
    return 'dog can run fast'
  def smell(self):
    return 'dog can smell'

dog=Animal()  # Creating object of Animal class

# %%
dog.bark()  # Calling bark() method
# Out:
# 'dog can bark'

# %%
Animal.bark(dog)  # Calling method using class and passing object manually
# Out:
# 'dog can bark'

# %% [markdown]
# # GLOBAL VARIABLES

# %%
name='rajendra'   # Global variable
age=24            # Global variable

class Myself():
  name='raj'
  age=30
  def Intro(self):   # Method
    return f"My name is {name} and My age is {age}"    # Uses global variables
m=Myself()  # Creating object

# %%
m.Intro()  # Calling method
# Out:
# 'My name is rajendra and My age is 24'

# %%
#USING SELF VARIABLES
name='rajendra'
age=24

class Myself():
  name='raj'
  age=30
  def Intro(self):
    return f"My name is {self.name} and My age is {self.age}"   # Uses instance/class variables

m=Myself()

# %%
m.Intro()
# Out:
# 'My name is raj and My age is 30'

# %% [markdown]
# # INSTANCE VARIABLE CREATION

# %%
class Example:
    def create_Name(self, Name):
        self.Name = Name    # Instance variable created dynamically

    def Display_Name(self):
        return self.Name

    def greet(self):
        return f"Welcome to app {self.Name}"

e = Example()

# %%
e.create_Name('panu')

# %%
e.Display_Name()
# Out:
# 'panu'

# %%
e.greet()
# Out:
# 'Welcome to app panu'

# %% [markdown]
# # MULTIPLE OBJECTS

# %%
class meth():
  def Detail(self,name,age):
    self.name=name
    self.age=age
  def Minus(self):
    self.age=self.age-1

  def display(self):
    print(f"name:- {self.name}\n age:- {self.age}")

a=meth()
b=meth()
c=meth()
d=meth()

# %%
a.Detail('raj',25)
b.Detail('veer',25)
c.Detail('manu',30)
d.Detail('Vinit',35)

# %%
a.display()
b.display()
c.display()
d.display()
# Out:
# name:- raj
#  age:- 25
# name:- veer
#  age:- 25
# name:- manu
#  age:- 30
# name:- Vinit
#  age:- 35

# %%
b.Minus()
b.display()
# Out:
# name:- veer
#  age:- 19

# %%
c.Minus()
c.display()
# Out:
# name:- manu
#  age:- 28

# %%
d.Minus()
d.display()
# Out:
# name:- Vinit
#  age:- 29

# %% [markdown]
# # CONSTRUCTOR (__init__)

# %%
class BankAccount:
    def __init__(self, name, balance=0):   # Constructor automatically runs
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited ₹{amount}. New balance: ₹{self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"Withdrew ₹{amount}. New balance: ₹{self.balance}")
        else:
            print("Insufficient funds!")

    def display(self):
        print(f"Account Holder: {self.name}\nBalance: ₹{self.balance}")


acc = BankAccount("Rahul", 1000)
acc.deposit(500)
acc.withdraw(300)
acc.display()
# Out:
# Deposited ₹500. New balance: ₹1500
# Withdrew ₹300. New balance: ₹1200
# Account Holder: Rahul
# Balance: ₹1200

# %%
class car:
  model='BMW'
  color='RED'

  def car1(self,model,color):
    self.model='toyota'
    self.color='blue'
  def car2(self,model,color):
    self.model=model
    self.color=color

  def start(self):
    print(f"The {self.color} {self.model} is running")

c=car()
c.car1('pulsar','purple')
c.car2('honda','white')

# %%
c.start()
# Out:
# The RED BMW is running

# %%
c.car1('pulsar','purple')
c.start()
c.car2('honda','white')
c.start()
# Out:
# The blue toyota is running
# The white honda is running

# %%
# CAR WITH CONSTRUCTOR
class car:
  def __init__ (self,model,color):
    self.model = model
    self.color = color

  def start(self):
    print(f"The {self.color} {self.model} is running")

# %%
c1=car('BMW','Black')
c1.start()
# Out:
# The Black BMW is running

# %%
name='Raj'
class ABC():
  age=28

  def __init__(self,salary):
    self.salary=salary
z=ABC(30000)

# %%
# ACCESS MODIFIERS
class absc():
  a=10     # public
  _b=20    # protected (convention)
  __c=30   # private

m=absc()
m.a       # Accessing public variable
# Out:
# 10

# %%
# INHERITANCE
class mom():
  hair='black'
  eyes='dark_black'
  def Intro(self):
    return 'I am class mom'

class dad():
  hair='brown'
  nose='sharp'
  eyes='black'
  voice='loud'

  def Intro(self):
    return 'I am dad class'

class raj(mom,dad):
  pass

x=raj()

# %%
x.eyes
# Out:
# 'dark_black'

# %%
x.voice
# Out:
# 'loud'

# %%
# METHOD OVERRIDING
class mom():
  hair='black'
  eyes='dark_black'
  def Intro(self):
    return 'I am class mom'

class dad():
  hair='brown'
  nose='sharp'
  eyes='black'
  voice='loud'

  def Intro(self):
    return 'I am dad class'

class raj(mom,dad):
  def Intro(self):
    return 'i am child class'

x=raj()

# %%
# PRIVATE VARIABLES (GAME)
class Game:
   def __init__(self,name):
    self.name=name
    self.__score=0
    self.__life=3

   def View_Detail(self):
    print(f"name {self.name}\n score {self.__score} life {self.__life}")

   def punch(self):
    self.__score=self.__score +15

   def kick(self):
    self.__score=self.__score +10

   def diff(self):
    self.__score=self.__score -5

   def stabbed(self):
    if self.__life>0:
      self.__life=self.__life -1
      if self.__life == 0:
        print(" You lost all your lives! Game Over!")
    else:
        print("Game Over! No life left.")

# %%
g=Game("panu")
g.View_Detail()
# Out:
# name panu
#  score 0 life 3

# %%
g.punch()

# %%
g.View_Detail()
# Out:
# name panu
#  score 15 life 3

# %%
g.kick()

# %%
g.View_Detail()
# Out:
# name panu
#  score 15 life 3

# %%
g.stabbed()

# %%
g.View_Detail()
# Out:
# name panu
#  score 15 life 2

# %%
class Employee():      # Defining Employee class
  empcount=0           # Class variable to count total employees
  incmt=1.10            # Class variable for salary increment rate

  def __init__(self,first,last,salary):   # Constructor runs when object is created
    self.first=first      # Instance variable for first name
    self.last=last        # Instance variable for last name
    self.salary=salary    # Instance variable for salary
    self.email= first.lower()+"."+last.lower()+"@quastech.com"   # Email generated automatically
    Employee.empcount +=1   # Increment employee count

  def fullname(self):      # Method to return full name
   return f"{self.first.title()} {self.last.title()}"

  def increment(self):     # Method to increase salary
    self.salary=int(self.salary*Employee.incmt)

# %%
emp1=Employee("raj","desai",30000)    # Creating employee object
emp2=Employee("rajni","kenjale",35000)
emp3=Employee("sagar","gole",10000)

# %%
emp2.email # Accessing email of emp2
emp2.incmt  # Accessing class variable using object
# Out:
# 1.1

# %%
# INHERITANCE (DEVELOPER CLASS)
class Developer(Employee):     # Developer inherits from Employee
  def __init__(self, first, last, salary,prog_lang):  # Constructor of child class
    super().__init__(first, last, salary)   # Calling parent constructor
    self.prog_lang=prog_lang    # Programming language of developer

# %%
dev1=Developer("raj","desai",35000,"python")
dev2=Developer("kiran","yadav",50000,"SQL")
dev3=Developer("rani","kadam",60000,"R")

# %%
dev1.fullname() # Calling inherited method
dev1.email      # Inherited property
dev1.prog_lang  # Child class property
# Out:
# 'python'

# %%
dev2.email
# Out:
# 'kiran.yadav@quastech.com'

# %%
# MANAGER CLASS (HAS-A RELATIONSHIP)
class Manager(Employee):  # Manager inherits Employee
  def __init__(self,first,last,salary,employees=None):
    super().__init__(first,last,salary)  # Calling parent constructor

    if (employees is None):
      self.employees=[]   # Empty employee list
    else:
      self.employees=employees # Assign provided employee list

  def addemp(self,emp):   # Adds employee if not present
    if emp not in self.employees:
      self.employees.append(emp)
  def removemp(self,emp):  # Removes employee if present
    if emp in self.employees:
      self.employees.remove(emp)
  def print_emps(self):   # Prints all employees under manager
    for emp in self.employees:
      print("-->",emp.fullname())

# %%
mg1=Manager("tanu","pawar",125000,[emp1,emp2])

# %%
mg1.first # Access manager first name
mg1.email # Access manager email
mg1.addemp(emp3) # Adding new employee

# %%
mg1.print_emps()
# Out:
# --> Raj Desai
# --> Rajni Kenjale
# --> Sagar Gole

# %%
mg2=Manager("john","tailor",200000,[dev1,dev2])

# %%
mg2.email
#mg2.addemp(dev3)
#mg2.removemp(dev3)
mg2.print_emps()
# Out:
# --> Raj Desai
# --> Kiran Yadav

# %% [markdown]
# # BANK PROJECT (INHERITANCE + ENCAPSULATION)

# %%
class user():      # Base user class
  def __init__(self,name,age,gender):
    self.name=name
    self.age=age
    self.gender=gender

  def showdetail(self):
    # Displays user details
    print("personal details:-")
    print(f"name :- {self.name.title()}")
    print(f"age :- {self.age}")
    print(f"gender :- {self.gender.title()}")

# %%
# Creating user object
pranali=user("pranali patil",20,"female")

# %%
# Displaying details
pranali.showdetail()
# Out:
# personal details:-
# name :- Pranali Patil
# age :- 20
# gender :- Female

# %%
class bank(user):   # bank class inherits user
  __balance=0       # Private balance variable
  __usercount=0     # Private class variable

  def __init__(self,name,age,gender):
    super().__init__(name,age,gender)   # Calling parent constructor
    bank.__usercount +=1                # Increment user count
    self.accountno = f"bnkacco000{bank.__usercount}"   # Generate unique account number

  # def d(self):
  #    print(f"{self.__usercount}")

  # def a(self):
  #   print(f"{self.accountno}")

  def deposite(self,amount):
    self.amount=amount
    self.__balance += self.amount
    print(f"account balance is updated:- rs. {self.__balance}")

  def withdraw(self,amount):
    self.amount=amount
    if(self.amount> self.__balance):
      print(f"insufficient amount,balance available:- rs.{self.__balance}")
    elif(100<=self.amount<=self.__balance):
      print("thank you for visiting")
      self.__balance -=self.amount
      print(f"current balance is :- rs {self.__balance}")
    else:
      print(f"you cannot withdraw less than rs.100")

  def viewbalance(self):
    self.showdetail()
    print(f"ac no:- {self.accountno}")
    print(f"current balance is:- {self.__balance}")

  def transfer(self,username,amount):

    self.amount=amount
    if(self.amount>self.__balance):
      print(f"insufficient amount, balance available :- rs. {self.__balance}")
    elif(1<=self.amount<=self.__balance):
      username.__balance += self.amount
      self.__balance=self.amount
      print("amount transferred auccessfully")
      print(f"current balance is :- {self.__balance}")
    else:
      print("you cannot transfer less then rs.1")

# %%
kasu=bank("kaustubh kadam",23,"male")
sharu=bank("shravani kadam",21,"female")

# %%
kasu.deposite(4000)
# Out:
# account balance is updated:- rs. 4000

# %%
sharu.deposite(10000)
# Out:
# account balance is updated:- rs. 10000

# %%
sharu.withdraw(5000)
# Out:
# thank you for visiting
# current balance is :- rs 5000

# %%
sharu.transfer(kasu,2500)
# Out:
# amount transferred auccessfully
# current balance is :- 2500

# %%
kasu.viewbalance()
# Out:
# personal details:-
# name :- Kaustubh Kadam
# age :- 23
# gender :- Male
# ac no:- bnkacco0001
# current balance is:- 6500

# %%
sharu.viewbalance()
# Out:
# personal details:-
# name :- Shravani Kadam
# age :- 21
# gender :- Female
# ac no:- bnkacco0002
# current balance is:- 2500

# %%
# SUPER() METHOD EXAMPLE
class mom():
  def mun(self):
    print(" i love my son")

class child(mom):
  def a(self):
    super().mun()    # Calls parent class method
    print("i love my mom")

# %%
m=mom()
m.mun()
# Out:
#  i love my son

# %%
c=child()

# %%
c.a()
# Out:
#  i love my son
# i love my mom
