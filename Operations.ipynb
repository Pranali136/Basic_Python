# %% [markdown]
# #CONCATENATION

# %%
#String Concatenation
a='raj'
b='kadam'
print(a+b)
# Out:
# rajkadam

# %%
a=(1,2)
b=(3,4)
print(a+b)
# Out:
# (1, 2, 3, 4)

# %%
a='raj'
b='kadam'
print(a+" "+b)
# Out:
# raj kadam

# %%
#TUPLECONCATENATION
a=(1,2)
b=(3,4)
print(a+(6,7,8 ))
print(a+()+(1,2 ))
# Out:
# (1, 2, 6, 7, 8)
# (1, 2, 1, 2)

# %%
#LIST CONCATENATION
a=['r','b']
b=['k','c']
print(a,b)
# Out:
# ['r', 'b'] ['k', 'c']

# %%
l=['r','b']
m=['k','c']
print(l+[6,7]+[],m)
# Out:
# ['r', 'b', 6, 7] ['k', 'c']

# %%
l=['r','b']
m=['k','c']
print(l-m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-121831764.py in <cell line: 0>()
#       1 l=['r','b']
#       2 m=['k','c']
# ----> 3 print(l-m)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %% [markdown]
# #REPLICATION

# %%
#STRING REPLICATION
a='meet'
print(a*3)
print((a+" ")*3)
# Out:
# meetmeetmeet
# meet meet meet

# %%
a='meet'
print("@"+(a*3)+"@")
# Out:
# @meet@meet@meet@@

# %%
#TUPLE REPLICATION
q=(7,8)
print(q*2)
# Out:
# (7, 8, 7, 8)

# %%
q=(7,8)
print(((q+(9,10))*2)+(11,12))
# Out:
# (7, 8, 9, 10, 7, 8, 9, 10, 11, 12)

# %%
 #LIST REPLICATION
  s=['r','k']
 print((s + []) * 2)
# Out:
# ['r', 'k', 1, 'r', 'k', 1]

# %% [markdown]
# #INDEXING & SLICING

# %%
h='raj kadam'
print(h[0]+h[4])
print(h[0]+h[-5])
# Out:
# rk
# rk

# %%
#SLICING
g=(-1,1,1.1,'raj','meet')
f=(g[2],g[0],g[3][0],g[3][1],g[4][1],g[4][0])
print(f)
# Out:
# (1.1, -1, 'r', 'a', 'e', 'm')

# %%
f=(g[3]+g[4][0]+g[3][1]+g[4][3]+g[3][1])
print(f)
# Out:
# rajmata

# %%
f=(g[3]+g[4][0]+g[3][1]+g[4][3]+g[3][1],g[1],g[3][0]+g[3][1]+g[4][0])
print(f)
# Out:
# ('rajmata', 1, 'ram')

# %%
  p=['meet','madhu','pranali','jay']
  q=[p[-4][-1]+p[-1][-2]+p[-2][-6]+p[-1][-2]+p[-1][-3]+p[-3][-1]]
  print(q)
# Out:
# ['taraju']
